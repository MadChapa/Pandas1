# %%
import pandas as pd
import numpy as np

# %%
dict1={
    "name":['santosh','keshav','nabin','susil'],
    "marks":[95,98,99,90],
    "city":["pokhara",syangja","bajhang","chitwan"]
    
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks     city
# 0  santosh     95  pokhara
# 1   keshav     98  syangja
# 2    nabin     99  bajhang
# 3    susil     90  chitwan

# %%
df.to_csv("Friends_info.csv")   #csv mah convert gareko

# %%
df.head(2)  #first ko 2 ota rows dekhuxa
# Out:
#       name  marks     city
# 0  santosh     95  pokhara
# 1   keshav     98  syangja

# %%
df.tail(2)  #last ko 2 ota rows dekhuxa
# Out:
#     name  marks     city
# 2  nabin     99  bajhang
# 3  susil     90  chitwan

# %%
df.describe()  #stastical analysis garxa
# Out:
#            marks
# count   4.000000
# mean   95.500000
# std     4.041452
# min    90.000000
# 25%    93.750000
# 50%    96.500000
# 75%    98.250000
# max    99.000000
